# %% [markdown]
# **Shibu Mohapatra MSC AI**

# %% [markdown]
# # UNIT 3: Context Natural Language Generation

# %% [markdown]
# ## Text Generation

# %%
! pip install markovify

# %%
import pandas as pd
import markovify
import random

# %%
input = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/abcnews-date-text.csv')

input.head(10)
# Out:
#    publish_date                                      headline_text
# 0      20030219  aba decides against community broadcasting lic...
# 1      20030219     act fire witnesses must be aware of defamation
# 2      20030219     a g calls for infrastructure protection summit
# 3      20030219           air nz staff in aust strike for pay rise
# 4      20030219      air nz strike to affect australian travellers
# 5      20030219                  ambitious olsson wins triple jump
# 6      20030219         antic delighted with record breaking barca
# 7      20030219  aussie qualifier stosur wastes four memphis match
# 8      20030219       aust addresses un security council over iraq
# 9      20030219         australia is locked into war timetable opp

# %%
input.headline_text[random.sample(range(100), 10)]
# Out:
# 5                     ambitious olsson wins triple jump
# 43       dying korean subway passengers phoned for help
# 25    code of conduct toughens organ donation regula...
# 33        crean tells alp leadership critics to shut up
# 73    investigations underway into death toll of korean
# 34                   dargo fire threat expected to rise
# 37       dent downs philippoussis in tie break thriller
# 49                four injured in head on highway crash
# 88                        man charged over cooma murder
# 65    hacker gains access to eight million credit cards
# Name: headline_text, dtype: object

# %%
model = markovify.NewlineText(input.headline_text, state_size = 2)

# %%
for i in range(10):
  print(model.make_sentence())
# Out:
# police union welcomes firefighting report
# push continues for act cabinet to consider childs testimony
# why you should appoint new govt ministers questioned over collie road deaths prompt kikuyu warning
# hunt for men charged over stabbing
# zola gives ac milan eyes chelsea
# govt under fire ahead of debut
# man drowns trying to reclaim mosul from is may have been stolen
# nelson slams labors leadership troubles can be his again
# mav unhappy local govt group seeks leniency
# mike pompeo praises australia us election dead people still debating whether booing adam

# %%
model1 = markovify.NewlineText(input.headline_text, state_size = 3)
model2 = markovify.NewlineText(input.headline_text, state_size = 4)

# %%
for i in range(5):
  print(model1.make_sentence())
# Out:
# father recounts how he tried to save mother from floodwaters
# leighton shareholders to face write downs of up to 150 drowned or shot fleeing boko haram ambush in nigeria
# green the speech abbott could have made pine blaze worse
# power prices lower under emissions trading scheme needed
# police investigate fatal crash at red hill

# %%
for i in range(10):
    temp = model2.make_sentence()
    if temp is not None: 
        print(temp)
# Out:
# thousands march in hong kong for drug trafficking

# %%
# model11 = markovify.NewlineText(input.headline_text, state_size = 2)
# model12 = markovify.NewlineText(input.headline_text, state_size = 2)
# model_combo = markovify.combine([ model11, model12 ], [ 1.5, 1 ])

# for i in range(5):
#     print(model_combo.make_sentence())
